# %%
import pandas as pd

# %%
filename = 'psw18vwall.xls'
sheetname = 'Data 1'

# %%
! pip install xlrd
# Out:
# ...
#      ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#      ---------------- --------------------- 41.0/96.5 kB 991.0 kB/s eta 0:00:01
#      ---------------------------------------- 96.5/96.5 kB 1.4 MB/s eta 0:00:00
# ...

# %%
df = pd.read_excel(filename, sheet_name=sheetname)
df
# Out:
#          Back to Contents                Data 1: W Diesel Prices - All Types  \
# 0               Sourcekey                              EMD_EPD2D_PTE_NUS_DPG
# 1                    Date  Weekly U.S. No 2 Diesel Retail Prices  (Dollar...
# 2     1994-03-21 00:00:00                                              1.106
# 3     1994-03-28 00:00:00                                              1.107
# 4     1994-04-04 00:00:00                                              1.109
# ...                   ...                                                ...
# 1562  2024-02-12 00:00:00                                              4.109
# 1563  2024-02-19 00:00:00                                              4.109
# 1564  2024-02-26 00:00:00                                              4.058
# 1565  2024-03-04 00:00:00                                              4.022
# 1566  2024-03-11 00:00:00                                              4.004
#
# ...

# %%
east_cost_oil_df = df[['Back to Contents', 'Unnamed: 2']].iloc[2:].copy()
east_cost_oil_df
# Out:
#          Back to Contents Unnamed: 2
# 2     1994-03-21 00:00:00      1.119
# 3     1994-03-28 00:00:00      1.115
# 4     1994-04-04 00:00:00      1.122
# 5     1994-04-11 00:00:00      1.119
# 6     1994-04-18 00:00:00      1.115
# ...                   ...        ...
# 1562  2024-02-12 00:00:00      4.201
# 1563  2024-02-19 00:00:00       4.24
# 1564  2024-02-26 00:00:00      4.185
# 1565  2024-03-04 00:00:00      4.151
# 1566  2024-03-11 00:00:00       4.12
#
# [1565 rows x 2 columns]

# %%
east_cost_oil_df.columns = ['date', 'retail_price']
east_cost_oil_df
# retail_price is retail price of oil in Dollars per Gallon at the east coast of US
# Out:
#                      date retail_price
# 2     1994-03-21 00:00:00        1.119
# 3     1994-03-28 00:00:00        1.115
# 4     1994-04-04 00:00:00        1.122
# 5     1994-04-11 00:00:00        1.119
# 6     1994-04-18 00:00:00        1.115
# ...                   ...          ...
# 1562  2024-02-12 00:00:00        4.201
# 1563  2024-02-19 00:00:00         4.24
# 1564  2024-02-26 00:00:00        4.185
# 1565  2024-03-04 00:00:00        4.151
# 1566  2024-03-11 00:00:00         4.12
#
# [1565 rows x 2 columns]

# %%
east_cost_oil_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 2 to 1566
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1565 non-null   object
#  1   retail_price  1565 non-null   object
# dtypes: object(2)
# memory usage: 24.6+ KB

# %%
years = range(2019, 2024)
list(years)
# Out:
# [2019, 2020, 2021, 2022, 2023]

# %%
east_cost_oil_df['date'] = pd.to_datetime(east_cost_oil_df['date'])
east_cost_oil_df['retail_price'] = east_cost_oil_df['retail_price'].astype(float)

east_cost_oil_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 2 to 1566
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1565 non-null   datetime64[ns]
#  1   retail_price  1565 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 24.6 KB

# %%
east_cost_oil_df
# Out:
#            date  retail_price
# 2    1994-03-21         1.119
# 3    1994-03-28         1.115
# 4    1994-04-04         1.122
# 5    1994-04-11         1.119
# 6    1994-04-18         1.115
# ...         ...           ...
# 1562 2024-02-12         4.201
# 1563 2024-02-19         4.240
# 1564 2024-02-26         4.185
# 1565 2024-03-04         4.151
# 1566 2024-03-11         4.120
#
# [1565 rows x 2 columns]

# %%
east_cost_oil_df_2019_2023 = east_cost_oil_df[east_cost_oil_df['date'].dt.year.isin(years)]
east_cost_oil_df[east_cost_oil_df['date'].dt.year.isin(years)].index
# Out:
# Int64Index([1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305,
#             ...
#             1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555],
#            dtype='int64', length=260)

# %%
indexes = range(1295, 1557) # add one sample margin
print(list(indexes)[:5])
print(list(indexes)[-5:])
# Out:
# [1295, 1296, 1297, 1298, 1299]
# [1552, 1553, 1554, 1555, 1556]

# %%
east_cost_oil_df.loc[indexes]
# Out:
#            date  retail_price
# 1295 2018-12-31         3.110
# 1296 2019-01-07         3.069
# 1297 2019-01-14         3.049
# 1298 2019-01-21         3.037
# 1299 2019-01-28         3.050
# ...         ...           ...
# 1552 2023-12-04         4.139
# 1553 2023-12-11         4.050
# 1554 2023-12-18         3.969
# 1555 2023-12-25         4.022
# 1556 2024-01-01         4.002
#
# [262 rows x 2 columns]

# %%
east_cost_oil_df_2019_2023 = east_cost_oil_df.loc[indexes]
east_cost_oil_df_2019_2023 = east_cost_oil_df_2019_2023.reset_index(drop=True)
east_cost_oil_df_2019_2023

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(east_cost_oil_df_2019_2023['date'], east_cost_oil_df_2019_2023['retail_price'])

plt.xlabel('Date')
plt.ylabel('Price ($/gal)')
plt.title('Retail oli prices, USA, East Coast, Dollars per Gallon')

plt.show()

# %%
east_cost_oil_df_2019_2023.to_csv('dataset_nyc_taxi/oil_prices.csv', index=False)

# %%
pd.read_csv('dataset_nyc_taxi/oil_prices.csv')
# Out:
#            date  retail_price
# 0    2018-12-31         3.110
# 1    2019-01-07         3.069
# 2    2019-01-14         3.049
# 3    2019-01-21         3.037
# 4    2019-01-28         3.050
# ..          ...           ...
# 257  2023-12-04         4.139
# 258  2023-12-11         4.050
# 259  2023-12-18         3.969
# 260  2023-12-25         4.022
# 261  2024-01-01         4.002
#
# [262 rows x 2 columns]
